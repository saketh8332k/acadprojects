# %%
# Import needed libraries

import pandas as pd
import numpy as np
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
train_data=pd.read_csv("Train.csv")

# %%
train_data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#from pandas_profiling import ProfileReport

# %%
#profile = ProfileReport(train_data,explorative=True)

# %%
#profile.to_widgets()

# %%
print ("Rows     : " ,train_data.shape[0])
print ("Columns  : " ,train_data.shape[1])
print ("\nFeatures : \n" ,train_data.columns.tolist())
print ("\nUnique values :  \n",train_data.nunique())
# Out:
# Rows     :  8523
# Columns  :  12
#
# Features :
#  ['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type', 'Item_MRP', 'Outlet_Identifier', 'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'Item_Outlet_Sales']
#
# Unique values :
#  Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
data_description = train_data.describe()
data_description
#this gives total characteristics of data
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
#data-cleaning-(1)fill null values
train_data.isnull().sum()
#calculating null values in data
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#filling null values in itemweight with median and outlet size with mode
train_data['Item_Weight'].fillna(train_data['Item_Weight'].median(),inplace=True)
train_data['Outlet_Size'].fillna(train_data['Outlet_Size'].mode()[0],inplace=True)

# %%
#No null values in data
train_data.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
data_description = train_data.describe()
data_description
#item weight and outlet size are changed compared to previous data description.
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count   8523.00000      8523.000000  8523.000000                8523.000000
# mean      12.81342         0.066132   140.992782                1997.831867
# std        4.22724         0.051598    62.275067                   8.371760
# min        4.55500         0.000000    31.290000                1985.000000
# 25%        9.31000         0.026989    93.826500                1987.000000
# 50%       12.60000         0.053931   143.012800                1999.000000
# 75%       16.00000         0.094585   185.643700                2004.000000
# max       21.35000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
import matplotlib.pyplot as plt

# %%
for i in train_data:
    print(train_data[i].unique())
# Out:
# ['FDA15' 'DRC01' 'FDN15' ... 'NCF55' 'NCW30' 'NCW05']
# [ 9.3    5.92  17.5   19.2    8.93  10.395 13.65  12.6   16.2   11.8
#  18.5   15.1   17.6   16.35   9.    13.35  18.85  14.6   13.85  13.
#   7.645 11.65   5.925 19.25  18.6   18.7   17.85  10.     8.85   9.8
#  13.6   21.35  12.15   6.42  19.6   15.85   7.39  10.195  9.895 10.895
#   7.905  9.195  8.365  7.97  17.7   19.35   8.645 15.6   18.25   7.855
#   7.825  8.39  12.85  19.     5.905  7.76  16.75  15.5    6.055  6.305
#  20.85  20.75   8.895 19.7    8.75  13.3    8.31  19.75  17.1   10.5
#   6.635 14.15   8.89   9.1    7.5   16.85   7.485 11.6   12.65  20.25
#   8.6    8.88  20.5   13.5    7.235  6.92   8.02  12.8   16.6   14.
#  16.    21.25   7.365 18.35   5.465  7.27   6.155 19.5   15.2   14.5
#  13.1   12.3   11.1   11.3    5.75  11.35   6.525 10.3    5.78  11.85
#  18.75   5.26  16.1    9.5   13.8   14.65   6.67   6.11  17.2    6.32
#   4.88   5.425 14.1    7.55  17.25  12.    10.1    7.785 13.15   8.5
# ...

# %%
#data cleaning-(2)handling redundant values
train_data['Item_Fat_Content'] = train_data['Item_Fat_Content'].map({"low fat":"Low Fat",
                                                                    "Low Fat":"Low Fat",
                                                                    "LF":"Low Fat",
                                                                    "Regular":"Regular",
                                                                    "reg":"Regular"})

# %%
print(train_data['Item_Fat_Content'].unique())
# Out:
# ['Low Fat' 'Regular']

# %% [markdown]
# scatterplot is used to determine relationship between 2 numerical variables, where each represents an observation in the dataset.

# %%
sns.scatterplot(x='Item_Visibility',y="Item_MRP",data=train_data,hue="Outlet_Location_Type")
#hue is color-code (by outlet location type).
# Out:
# <Axes: xlabel='Item_Visibility', ylabel='Item_MRP'>

# %%
sns.scatterplot(x='Item_Visibility',y="Item_MRP",data=train_data,hue="Outlet_Location_Type",legend=None)
#legend -  visual key that explains what each color on the plot represents.
# Out:
# <Axes: xlabel='Item_Visibility', ylabel='Item_MRP'>

# %% [markdown]
# # Observations

# %% [markdown]
# - If MRP is high,visibility is less of tier2 and tier3 but tier1 item visibility is very high to costly products
# - tier2 having no visibility more than 0.17 and 0.18
# - tier3 have some

# %%
plt.figure(figsize=(15,16))
sns.scatterplot(x='Item_MRP',y="Item_Outlet_Sales",data=train_data,hue="Item_Type")
# Out:
# <Axes: xlabel='Item_MRP', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# # Observations

# %% [markdown]
# - Household items makes more than 12000 of sales with low MRP
# - Fruits also make more than 10000 sales

# %% [markdown]
# # Check the countplots of categorical column
# countplot is used to display the counts of observations within each categorical bin using bars.

# %%
sns.countplot(x='Item_Fat_Content',data=train_data)
# Out:
# <Axes: xlabel='Item_Fat_Content', ylabel='count'>

# %%
sns.countplot(x='Outlet_Type',data=train_data)
# Out:
# <Axes: xlabel='Outlet_Type', ylabel='count'>

# %%
train_data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
categorical_data=train_data.select_dtypes(include="object")

# %%
categorical_data
# Out:
#      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# ...              ...              ...                    ...
# 8518           FDF22          Low Fat            Snack Foods
# 8519           FDS36          Regular           Baking Goods
# 8520           NCJ29          Low Fat     Health and Hygiene
# 8521           FDN46          Regular            Snack Foods
# 8522           DRG01          Low Fat            Soft Drinks
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 1  Supermarket Type1
# 1               OUT018      Medium               Tier 3  Supermarket Type2
# ...

# %%
column_names=categorical_data.columns

# %%
for i in column_names:
    print(train_data[i].unique())
# Out:
# ['FDA15' 'DRC01' 'FDN15' ... 'NCF55' 'NCW30' 'NCW05']
# ['Low Fat' 'Regular']
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
# ['OUT049' 'OUT018' 'OUT010' 'OUT013' 'OUT027' 'OUT045' 'OUT017' 'OUT046'
#  'OUT035' 'OUT019']
# ['Medium' 'High' 'Small']
# ['Tier 1' 'Tier 3' 'Tier 2']
# ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']

# %%
from sklearn import preprocessing
label=preprocessing.LabelEncoder()

categorical_data['Item_Fat_Content']=label.fit_transform(categorical_data['Item_Fat_Content'])
categorical_data['Item_Type']=label.fit_transform(categorical_data['Item_Type'])
categorical_data['Outlet_Size']=label.fit_transform(categorical_data['Outlet_Size'])
categorical_data['Outlet_Location_Type']=label.fit_transform(categorical_data['Outlet_Location_Type'])
categorical_data['Outlet_Type']=label.fit_transform(categorical_data['Outlet_Type'])
#categorical_data['Item_Identifier']=label.fit_transform(categorical_data['Item_Identifier'])
#categorical_data['Outlet_Identifier']=label.fit_transform(categorical_data['Outlet_Identifier'])
categorical_data['Item_Outlet_Sales']=train_data['Item_Outlet_Sales']

# %%
categorical_data
# Out:
#      Item_Identifier  Item_Fat_Content  Item_Type Outlet_Identifier  \
# 0              FDA15                 0          4            OUT049
# 1              DRC01                 1         14            OUT018
# 2              FDN15                 0         10            OUT049
# 3              FDX07                 1          6            OUT010
# 4              NCD19                 0          9            OUT013
# ...              ...               ...        ...               ...
# 8518           FDF22                 0         13            OUT013
# 8519           FDS36                 1          0            OUT045
# 8520           NCJ29                 0          8            OUT035
# 8521           FDN46                 1         13            OUT018
# 8522           DRG01                 0         14            OUT046
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0               1                     0            1          3735.1380
# ...

# %% [markdown]
# heatmap - visualize correlation between variables, where values are depicted by color.

# %%
import seaborn as sns
X = categorical_data.iloc[:,0:21]  #independent columns
y = categorical_data.iloc[:,-1]    #target column i.e price range
#get correlations of each features in dataset
corrmat = categorical_data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(10,10))
#plot heat map
g=sns.heatmap(categorical_data[top_corr_features].corr(),annot=True,cmap="RdYlGn")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 5
#       3 y = categorical_data.iloc[:,-1]    #target column i.e price range
#       4 #get correlations of each features in dataset
# ----> 5 corrmat = categorical_data.corr()
#       6 top_corr_features = corrmat.index
#       7 plt.figure(figsize=(10,10))
#
# File d:\Bigmart-sales-prediction-main\Bigmart-sales-prediction-main\venv\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# ...

# %%
numerical_columns = train_data.select_dtypes(exclude="object")

# %%
numerical_columns
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Outlet_Sales
# 0             3735.1380
# 1              443.4228
# 2             2097.2700
# ...

# %%
import seaborn as sns
X = numerical_columns.iloc[:,0:21]  #independent columns
y = numerical_columns.iloc[:,-1]    #target column i.e price range
#get correlations of each features in dataset
corrmat = numerical_columns.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(10,10))
#plot heat map
g=sns.heatmap(numerical_columns[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
cols = numerical_columns.columns

# %%
cols
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# Observing outliers in numerical data using boxplot(robust scaling)

# %% [markdown]
# Boxplot is used to show the shape of the distribution, its median,quartiles and outliers.

# %%
for i in cols:
    plt.figure(figsize=(8,6))
    sns.boxplot(data=train_data,x=i)
    plt.xlabel(i,fontsize=13)

# %% [markdown]
# displot-for distribution plots

# %%
for i in cols:
    plt.figure(figsize=(8,3))
    sns.displot(train_data[i])

# %%
train_data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#data cleaning-(3)useless columns
no_need=["Item_Identifier"]

# %%
train_data.drop(no_need,axis=1,inplace=True)

# %%
train_data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
#data cleaning-(4)removing outliers
def remove(dataframe,column):
    Q3 = dataframe[column].quantile(0.75)
    Q1 = dataframe[column].quantile(0.25)
    IQR = Q3 - Q1
    upper = Q3 + (1.5 * IQR)
    lower = Q1 + (1.5 * IQR)
    df_no_outliers = dataframe[(dataframe[column]>lower) & (dataframe[column]<upper)]
    return df_no_outliers

# %%
#pd.get_dummies()-converts categorical data into dummy or indicator variables(that r binary(0,1)).used in ml when machine needs numerical i/p.
final_data=pd.get_dummies(train_data,drop_first=True)

# %%
final_data
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Outlet_Sales  Item_Fat_Content_Regular  Item_Type_Breads  \
# ...

# %%
#preparing data for model.x = independent variables,y = dependent variable.
X=final_data.drop(columns=['Item_Outlet_Sales'],axis=1)
Y=final_data['Item_Outlet_Sales']

# %% [markdown]
# sci-kit learn - poerful and open-source python library used for classification, regression, clustering and data preprocessing.

# %%
#train-test-split - splits data into training and testing sets.
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=0)

# %% [markdown]
# Random-forest regressor - uses an ensemble of decision trees to predict continuous target variables, improving accuracy and reducing variance through averaging predictions from multiple trees trained on different subsets of the data.

# %%
#ensemble - combines predictions of multiple models to improve generalizability/robustness over a single model.
#RandomForestRegressor - ensemble learning method that operates by constructing multiple decision trees during training phase.
from sklearn.ensemble import RandomForestRegressor

# %%
#model.fit()-fits the model to the training data.
model=RandomForestRegressor()
model.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
prediction1=model.predict(X_test)

# %%
print("item_sales: ",prediction1)
# Out:
# item_sales:  [2498.221418 1524.675342 2560.786644 ... 2699.38623   746.474986
#  2116.198694]

# %% [markdown]
# xgbregressor - (eXtreme Gradient Boosting) is a powerful, open-source machine learning library used for regression and classification problems, known for its speed, efficiency, and ability to handle large datasets

# %%
from xgboost import XGBRegressor

# %%
model2=XGBRegressor()
model2.fit(X_train,Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
prediction2=model2.predict(X_test)

# %%
print(f"item_sales: {prediction2}")
# Out:
# item_sales: [2360.1755 1530.6058 2468.9626 ... 2507.2698  734.7404 2487.282 ]

# %%
#xgb_reg = XGBRegressor()
#xgb_reg.fit(X_train,Y_train)
#xgb_reg.score(X_train,Y_train)

#lin_reg = LinearRegression()
#lin_reg.fit(X, Y)
#lin_reg.score(X, Y)

#rf_reg = RandomForestRegressor()
#rf_reg.fit(X, Y)
#rf_reg.score(X, Y)

#ridge_reg = Ridge(alpha = 0.1)
#ridge_reg.fit(X, Y)
#ridge_reg.score(X, Y)

#lasso_reg = Lasso(alpha = 0.1)
#lasso_reg.fit(X, Y)
#lasso_reg.score(X, Y)

#ab_reg = AdaBoostRegressor(loss = "linear")
#ab_reg.fit(X, Y)
#ab_reg.score(X, Y)

#gb_reg = GradientBoostingRegressor(max_depth = 7, max_features = 4, n_estimators = 35)
#gb_reg.fit(X_train,Y_train)
#gb_reg.score(X_train,Y_train)

# %%
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_squared_error,mean_absolute_error,accuracy_score

# %%
xgb_reg = XGBRegressor()
xgb_reg.fit(X_train,Y_train)
score = xgb_reg.score(X_train,Y_train)
print(f"Score: {score}")
# Out:
# Score: 0.8795670808689464

# %%
# Calculate evaluation metrics correctly
r2 = r2_score(Y_train, xgb_reg.predict(X_train))  # Pass actual and predicted target values
mse = mean_squared_error(Y_train, xgb_reg.predict(X_train))/100000  
rmse = np.sqrt(mse)  
mae = mean_absolute_error(Y_train, xgb_reg.predict(X_train))

# Calculate Accuracy
accuracy = (1 - (mae / np.mean(Y_train))) * 100  

# Print Results
print(f"R² Score: {r2:.4f}")
print(f"Mean Squared Error (MSE): {mse: .2f}")
print(f"Root Mean Squared Error (RMSE): {rmse: .2f}")
print(f"Mean Absolute Error (MAE): {mae: .4f}")
print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# R² Score: 0.8796
# Mean Squared Error (MSE):  3.47
# Root Mean Squared Error (RMSE):  1.86
# Mean Absolute Error (MAE):  427.1100
# Model Accuracy: 80.40%

# %%
rf_reg = RandomForestRegressor()
rf_reg.fit(X, Y)
rf_reg.score(X, Y)
# Out:
# 0.9383878684613152

# %%
r2 = r2_score(Y_train, rf_reg.predict(X_train))  # Pass actual and predicted target values
mse = mean_squared_error(Y_train, rf_reg.predict(X_train))/100000  
rmse = np.sqrt(mse)  
mae = mean_absolute_error(Y_train, rf_reg.predict(X_train))

# Calculate Accuracy
accuracy = (1 - (mae / np.mean(Y_train))) * 100  

# Print Results
print(f"R² Score: {r2:.4f}")
print(f"Mean Squared Error (MSE): {mse: .2f}")
print(f"Root Mean Squared Error (RMSE): {rmse: .2f}")
print(f"Mean Absolute Error (MAE): {mae: .4f}")
print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# R² Score: 0.9382
# Mean Squared Error (MSE):  1.78
# Root Mean Squared Error (RMSE):  1.34
# Mean Absolute Error (MAE):  291.5638
# Model Accuracy: 86.62%

# %%
#pickle module - serializes objects so they can be saved to a file, and loaded in a program again later on.
import pickle
#file=open("final.pkl","wb")
#pickle.dump(model,file)

# %%
# Save the model as serialized object pickle
#wb - write binary
with open('newnew.pkl', 'wb') as file:
    pickle.dump(rf_reg, file)
